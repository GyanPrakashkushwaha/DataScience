# %%
from deepface import DeepFace
import os

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Face Detection

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Gyanprakash\\Desktop\\Data-Science\\Computer_Vision\\deep_face'

# %%
backends = ['opencv','ssd','dblib','mtcnn','retinaface','mediapipe']

# %%
face = DeepFace.detectFace(img_path=r'imgs\myimg_old.jpg',target_size=(224,224),detector_backend='opencv')
# Out:
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.

# %%
plt.imshow(face)

# %%
backends = {
    'opencv': 'opencv',
    'ssd': 'ssd',
    'dblib': 'dblib',
    'mtcnn': 'mtcnn',
    'retinaface': 'retinaface',
    'mediapipe': 'mediapipe',
    'VGG-Face':'VGG-Face',
    'OpenFace':'OpenFace'
}

# %%
for itmes,values in backends.items():
    try:
        face = DeepFace.detectFace(img_path=r'imgs\myimg_old.jpg',target_size=(224,224),detector_backend=f'{itmes}')
        plt.imshow(face)
        plt.title(values)
        plt.show()
    except:
        pass
# Out:
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ...
# 1/1 [==============================] - 0s 178ms/step
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.

# %%
for itmes,values in backends.items():
    try:
        face = DeepFace.extract_faces(img_path=r'imgs\myimg_old2.jpg',target_size=(224,224),detector_backend=f'{itmes}')
        plt.imshow(face[0]['face'])
        plt.title(values)
        plt.show()
    except:
        pass

# %%
face = DeepFace.extract_faces(img_path=r'imgs\myimg_old2.jpg',target_size=(224,224),detector_backend=f'opencv')
plt.imshow(face[0]['face'])
# plt.title(values)
plt.show()

# %%
# face[0]['face']

# %%
face[0]['facial_area']
# Out:
# {'x': 482, 'y': 540, 'w': 1038, 'h': 1038}

# %%
X, y, width, height = face[0]['facial_area']

# %% [markdown]
# ## Varification

# %%
DeepFace.verify(img1_path=r'imgs\myimg_old2.jpg',img2_path=r'imgs\myimg_old.jpg')
# Out:
# {'verified': True,
#  'distance': 0.1587404758599925,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 482, 'y': 540, 'w': 1038, 'h': 1038},
#   'img2': {'x': 545, 'y': 561, 'w': 1007, 'h': 1007}},
#  'time': 15.5}
