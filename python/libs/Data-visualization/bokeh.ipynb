# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure ,output_file,show
from bokeh.sampledata.iris import flowers

output_file('iris.html')

p = figure(title='test_flower')
p.xaxis.axis_label = 'petal length'
p.yaxis.axis_label = 'petal width'
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="84f977f9-bc2c-4f25-a30c-8dc811f1b966" data-root-id="p1049" style="display: contents;"></div>

# %%
from bokeh.plotting import figure ,output_file,show
from bokeh.sampledata.iris import flowers

output_file('line.html')

p = figure(title='test_flower')
p.xaxis.axis_label = 'petal length'
p.yaxis.axis_label = 'petal width'
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="392da53d-be65-41ca-beab-181f3b26da5e" data-root-id="p1476" style="display: contents;"></div>
